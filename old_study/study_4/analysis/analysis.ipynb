# %% [markdown]
# # Process Human Data

# %%
import pandas as pd

# load data 
data = pd.read_csv('../simulation/data_w_simulation.csv')

print(data.shape)

# remove 'Finished' having value 0
data = data[data['Finished'] == 1]

# dimensions of the data
print(data.shape)
# Out:
# (356, 240)
# (350, 240)

# %%
# remove '8) English language reading/comprehension ability:' having value that is not 5
print(data.shape)
data = data[data['8) English language reading/comprehension ability:'] == 5]
print(data.shape)
# Out:
# (350, 240)
# (290, 240)

# %%
# exclude the 18th column having null values
print(data.shape)
data = data.dropna(subset=[data.columns[17]])
print(data.shape)
# Out:
# (290, 240)
# (276, 240)

# %%
import pandas as pd
import statsmodels.api as sm

# Define the predictors and target variables
predictors = ['openness', 'conscientiousness', 'extraversion', 'agreeableness', 'neuroticism']
# targets = ['ethic_sum', 'risk_sum']
targets = ['ethic_1_1', 'ethic_2_1', 'ethic_3_1', 'ethic_4_1', 'ethic_5_1']
# Function to perform simple linear regression and print results
def simple_linear_regression(X, y, predictor_name, target_name):
    X = sm.add_constant(X)  # Add a constant term to the predictor
    model = sm.OLS(y, X).fit()
    
    print(f"\nRegression Results for {predictor_name} predicting {target_name}")
    print(f"Coefficient: {model.params.iloc[1]:.4f}")
    print(f"P-value: {model.pvalues.iloc[1]:.4f}")
    print(f"R-squared: {model.rsquared:.4f}")
    print(f"Adjusted R-squared: {model.rsquared_adj:.4f}")
    print(f"Standard Error: {model.bse.iloc[1]:.4f}")
    print(f"T-statistic: {model.tvalues.iloc[1]:.4f}")
    print("\nModel Summary:")
    print(model.summary().tables[1])

# Perform regression for each predictor and target combination
for target in targets:
    print(f"\n{'='*50}")
    print(f"Analysis for {target}")
    print(f"{'='*50}")
    for predictor in predictors:
        X = data[predictor]
        y = data[target]
        simple_linear_regression(X, y, predictor, target)

print("\nRegression analysis complete.")
# Out:
# ==================================================
# Analysis for ethic_1_1
# ==================================================
#
# Regression Results for openness predicting ethic_1_1
# Coefficient: -0.0566
# P-value: 0.0055
# R-squared: 0.0278
# Adjusted R-squared: 0.0242
# Standard Error: 0.0202
# T-statistic: -2.7976
#
# Model Summary:
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          8.2910      0.893      9.284      0.000       6.533      10.049
# openness      -0.0566      0.020     -2.798      0.006      -0.096      -0.017
# ==============================================================================
#
# Regression Results for conscientiousness predicting ethic_1_1
# Coefficient: 0.0307
# P-value: 0.1842
# R-squared: 0.0064
# Adjusted R-squared: 0.0028
# Standard Error: 0.0230
# T-statistic: 1.3314
#
# Model Summary:
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                 4.4917      1.017      4.417      0.000       2.490       6.494
# conscientiousness     0.0307      0.023      1.331      0.184      -0.015       0.076
# =====================================================================================
#
# Regression Results for extraversion predicting ethic_1_1
# Coefficient: -0.0004
# P-value: 0.9872
# R-squared: 0.0000
# Adjusted R-squared: -0.0036
# Standard Error: 0.0221
# T-statistic: -0.0160
#
# Model Summary:
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            5.8431      0.848      6.887      0.000       4.173       7.513
# extraversion    -0.0004      0.022     -0.016      0.987      -0.044       0.043
# ================================================================================
#
# Regression Results for agreeableness predicting ethic_1_1
# Coefficient: -0.0042
# P-value: 0.8930
# R-squared: 0.0001
# Adjusted R-squared: -0.0036
# Standard Error: 0.0308
# T-statistic: -0.1346
#
# Model Summary:
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             6.0222      1.439      4.185      0.000       3.189       8.855
# agreeableness    -0.0042      0.031     -0.135      0.893      -0.065       0.057
# =================================================================================
#
# Regression Results for neuroticism predicting ethic_1_1
# Coefficient: -0.0451
# P-value: 0.0162
# R-squared: 0.0209
# Adjusted R-squared: 0.0173
# Standard Error: 0.0186
# T-statistic: -2.4191
#
# Model Summary:
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const           7.5216      0.716     10.503      0.000       6.112       8.931
# neuroticism    -0.0451      0.019     -2.419      0.016      -0.082      -0.008
# ===============================================================================
#
# ==================================================
# Analysis for ethic_2_1
# ==================================================
#
# Regression Results for openness predicting ethic_2_1
# Coefficient: 0.0222
# P-value: 0.3118
# R-squared: 0.0037
# Adjusted R-squared: 0.0001
# Standard Error: 0.0219
# T-statistic: 1.0133
#
# Model Summary:
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          6.5238      0.967      6.746      0.000       4.620       8.428
# openness       0.0222      0.022      1.013      0.312      -0.021       0.065
# ==============================================================================
#
# Regression Results for conscientiousness predicting ethic_2_1
# Coefficient: 0.0670
# P-value: 0.0064
# R-squared: 0.0268
# Adjusted R-squared: 0.0232
# Standard Error: 0.0244
# T-statistic: 2.7457
#
# Model Summary:
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                 4.5678      1.077      4.243      0.000       2.448       6.687
# conscientiousness     0.0670      0.024      2.746      0.006       0.019       0.115
# =====================================================================================
#
# Regression Results for extraversion predicting ethic_2_1
# Coefficient: -0.0061
# P-value: 0.7965
# R-squared: 0.0002
# Adjusted R-squared: -0.0034
# Standard Error: 0.0236
# T-statistic: -0.2582
#
# Model Summary:
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            7.7195      0.908      8.506      0.000       5.933       9.506
# extraversion    -0.0061      0.024     -0.258      0.796      -0.053       0.040
# ================================================================================
#
# Regression Results for agreeableness predicting ethic_2_1
# Coefficient: 0.0545
# P-value: 0.0978
# R-squared: 0.0100
# Adjusted R-squared: 0.0064
# Standard Error: 0.0328
# T-statistic: 1.6613
#
# Model Summary:
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             4.9593      1.532      3.238      0.001       1.944       7.975
# agreeableness     0.0545      0.033      1.661      0.098      -0.010       0.119
# =================================================================================
#
# Regression Results for neuroticism predicting ethic_2_1
# Coefficient: -0.0167
# P-value: 0.4075
# R-squared: 0.0025
# Adjusted R-squared: -0.0011
# Standard Error: 0.0201
# T-statistic: -0.8295
#
# Model Summary:
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const           8.1155      0.773     10.496      0.000       6.593       9.638
# neuroticism    -0.0167      0.020     -0.830      0.408      -0.056       0.023
# ===============================================================================
#
# ==================================================
# Analysis for ethic_3_1
# ==================================================
#
# Regression Results for openness predicting ethic_3_1
# Coefficient: -0.0002
# P-value: 0.9908
# R-squared: 0.0000
# Adjusted R-squared: -0.0036
# Standard Error: 0.0179
# T-statistic: -0.0116
#
# Model Summary:
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          4.0489      0.792      5.112      0.000       2.490       5.608
# openness      -0.0002      0.018     -0.012      0.991      -0.036       0.035
# ==============================================================================
#
# Regression Results for conscientiousness predicting ethic_3_1
# Coefficient: 0.0667
# P-value: 0.0009
# R-squared: 0.0398
# Adjusted R-squared: 0.0363
# Standard Error: 0.0198
# T-statistic: 3.3705
#
# Model Summary:
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                 1.1281      0.874      1.291      0.198      -0.593       2.849
# conscientiousness     0.0667      0.020      3.371      0.001       0.028       0.106
# =====================================================================================
#
# Regression Results for extraversion predicting ethic_3_1
# Coefficient: -0.0009
# P-value: 0.9611
# R-squared: 0.0000
# Adjusted R-squared: -0.0036
# Standard Error: 0.0193
# T-statistic: -0.0489
#
# Model Summary:
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            4.0755      0.742      5.493      0.000       2.615       5.536
# extraversion    -0.0009      0.019     -0.049      0.961      -0.039       0.037
# ================================================================================
#
# Regression Results for agreeableness predicting ethic_3_1
# Coefficient: 0.0211
# P-value: 0.4349
# R-squared: 0.0022
# Adjusted R-squared: -0.0014
# Standard Error: 0.0269
# T-statistic: 0.7820
#
# Model Summary:
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             3.0626      1.257      2.436      0.015       0.588       5.537
# agreeableness     0.0211      0.027      0.782      0.435      -0.032       0.074
# =================================================================================
#
# Regression Results for neuroticism predicting ethic_3_1
# Coefficient: -0.0139
# P-value: 0.3985
# R-squared: 0.0026
# Adjusted R-squared: -0.0010
# Standard Error: 0.0165
# T-statistic: -0.8456
#
# Model Summary:
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const           4.5618      0.632      7.218      0.000       3.318       5.806
# neuroticism    -0.0139      0.016     -0.846      0.398      -0.046       0.018
# ===============================================================================
#
# ==================================================
# Analysis for ethic_4_1
# ==================================================
#
# Regression Results for openness predicting ethic_4_1
# Coefficient: 0.0068
# P-value: 0.7128
# R-squared: 0.0005
# Adjusted R-squared: -0.0032
# Standard Error: 0.0183
# T-statistic: 0.3685
#
# Model Summary:
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          5.6087      0.809      6.937      0.000       4.017       7.200
# openness       0.0068      0.018      0.368      0.713      -0.029       0.043
# ==============================================================================
#
# Regression Results for conscientiousness predicting ethic_4_1
# Coefficient: 0.0036
# P-value: 0.8621
# R-squared: 0.0001
# Adjusted R-squared: -0.0035
# Standard Error: 0.0206
# T-statistic: 0.1738
#
# Model Summary:
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                 5.7457      0.911      6.308      0.000       3.953       7.539
# conscientiousness     0.0036      0.021      0.174      0.862      -0.037       0.044
# =====================================================================================
#
# Regression Results for extraversion predicting ethic_4_1
# Coefficient: 0.0187
# P-value: 0.3436
# R-squared: 0.0033
# Adjusted R-squared: -0.0004
# Standard Error: 0.0197
# T-statistic: 0.9486
#
# Model Summary:
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            5.1968      0.756      6.871      0.000       3.708       6.686
# extraversion     0.0187      0.020      0.949      0.344      -0.020       0.057
# ================================================================================
#
# Regression Results for agreeableness predicting ethic_4_1
# Coefficient: -0.0141
# P-value: 0.6096
# R-squared: 0.0010
# Adjusted R-squared: -0.0027
# Standard Error: 0.0275
# T-statistic: -0.5112
#
# Model Summary:
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             6.5549      1.284      5.103      0.000       4.026       9.084
# agreeableness    -0.0141      0.028     -0.511      0.610      -0.068       0.040
# =================================================================================
#
# Regression Results for neuroticism predicting ethic_4_1
# Coefficient: -0.0296
# P-value: 0.0781
# R-squared: 0.0113
# Adjusted R-squared: 0.0077
# Standard Error: 0.0167
# T-statistic: -1.7683
#
# Model Summary:
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const           7.0119      0.643     10.912      0.000       5.747       8.277
# neuroticism    -0.0296      0.017     -1.768      0.078      -0.063       0.003
# ===============================================================================
#
# ==================================================
# Analysis for ethic_5_1
# ==================================================
#
# Regression Results for openness predicting ethic_5_1
# Coefficient: -0.0124
# P-value: 0.4652
# R-squared: 0.0019
# Adjusted R-squared: -0.0017
# Standard Error: 0.0169
# T-statistic: -0.7314
#
# Model Summary:
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          3.6069      0.747      4.830      0.000       2.137       5.077
# openness      -0.0124      0.017     -0.731      0.465      -0.046       0.021
# ==============================================================================
#
# Regression Results for conscientiousness predicting ethic_5_1
# Coefficient: 0.0614
# P-value: 0.0012
# R-squared: 0.0378
# Adjusted R-squared: 0.0343
# Standard Error: 0.0187
# T-statistic: 3.2811
#
# Model Summary:
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                 0.3909      0.826      0.473      0.636      -1.235       2.017
# conscientiousness     0.0614      0.019      3.281      0.001       0.025       0.098
# =====================================================================================
#
# Regression Results for extraversion predicting ethic_5_1
# Coefficient: 0.0100
# P-value: 0.5847
# R-squared: 0.0011
# Adjusted R-squared: -0.0026
# Standard Error: 0.0182
# T-statistic: 0.5472
#
# Model Summary:
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            2.6924      0.700      3.847      0.000       1.315       4.070
# extraversion     0.0100      0.018      0.547      0.585      -0.026       0.046
# ================================================================================
#
# Regression Results for agreeableness predicting ethic_5_1
# Coefficient: 0.0352
# P-value: 0.1667
# R-squared: 0.0070
# Adjusted R-squared: 0.0033
# Standard Error: 0.0254
# T-statistic: 1.3867
#
# Model Summary:
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             1.4373      1.184      1.214      0.226      -0.893       3.767
# agreeableness     0.0352      0.025      1.387      0.167      -0.015       0.085
# =================================================================================
#
# Regression Results for neuroticism predicting ethic_5_1
# Coefficient: -0.0352
# P-value: 0.0229
# R-squared: 0.0188
# Adjusted R-squared: 0.0152
# Standard Error: 0.0154
# T-statistic: -2.2883
#
# Model Summary:
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const           4.3910      0.592      7.422      0.000       3.226       5.556
# neuroticism    -0.0352      0.015     -2.288      0.023      -0.066      -0.005
# ===============================================================================
#
# Regression analysis complete.

# %% [markdown]
# ## Examine the specific risk taking columns

# %%
# import pandas as pd
import statsmodels.api as sm

# Define the predictors and target variables
predictors = ['openness', 'conscientiousness', 'extraversion', 'agreeableness', 'neuroticism']
targets = ['ethic_sum', 'risk_sum']

# Function to perform simple linear regression and print results
def simple_linear_regression(X, y, predictor_name, target_name):
    X = sm.add_constant(X)  # Add a constant term to the predictor
    model = sm.OLS(y, X).fit()
    
    print(f"\nRegression Results for {predictor_name} predicting {target_name}")
    print(f"Coefficient: {model.params.iloc[1]:.4f}")
    print(f"P-value: {model.pvalues.iloc[1]:.4f}")
    print(f"R-squared: {model.rsquared:.4f}")
    print(f"Adjusted R-squared: {model.rsquared_adj:.4f}")
    print(f"Standard Error: {model.bse.iloc[1]:.4f}")
    print(f"T-statistic: {model.tvalues.iloc[1]:.4f}")
    print("\nModel Summary:")
    print(model.summary().tables[1])

# Perform regression for each predictor and target combination
for target in targets:
    print(f"\n{'='*50}")
    print(f"Analysis for {target}")
    print(f"{'='*50}")
    for predictor in predictors:
        X = data[predictor]
        y = data[target]
        simple_linear_regression(X, y, predictor, target)

print("\nRegression analysis complete.")
# Out:
# ==================================================
# Analysis for ethic_sum
# ==================================================
#
# Regression Results for openness predicting ethic_sum
# Coefficient: -0.0402
# P-value: 0.4486
# R-squared: 0.0021
# Adjusted R-squared: -0.0015
# Standard Error: 0.0530
# T-statistic: -0.7589
#
# Model Summary:
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         28.0792      2.340     11.999      0.000      23.472      32.686
# openness      -0.0402      0.053     -0.759      0.449      -0.145       0.064
# ==============================================================================
#
# Regression Results for conscientiousness predicting ethic_sum
# Coefficient: 0.2294
# P-value: 0.0001
# R-squared: 0.0537
# Adjusted R-squared: 0.0503
# Standard Error: 0.0581
# T-statistic: 3.9445
#
# Model Summary:
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                16.3242      2.567      6.360      0.000      11.271      21.377
# conscientiousness     0.2294      0.058      3.944      0.000       0.115       0.344
# =====================================================================================
#
# Regression Results for extraversion predicting ethic_sum
# Coefficient: 0.0212
# P-value: 0.7101
# R-squared: 0.0005
# Adjusted R-squared: -0.0031
# Standard Error: 0.0570
# T-statistic: 0.3721
#
# Model Summary:
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const           25.5272      2.194     11.636      0.000      21.208      29.846
# extraversion     0.0212      0.057      0.372      0.710      -0.091       0.134
# ================================================================================
#
# Regression Results for agreeableness predicting ethic_sum
# Coefficient: 0.0926
# P-value: 0.2458
# R-squared: 0.0049
# Adjusted R-squared: 0.0013
# Standard Error: 0.0796
# T-statistic: 1.1631
#
# Model Summary:
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            22.0363      3.713      5.935      0.000      14.727      29.346
# agreeableness     0.0926      0.080      1.163      0.246      -0.064       0.249
# =================================================================================
#
# Regression Results for neuroticism predicting ethic_sum
# Coefficient: -0.1406
# P-value: 0.0037
# R-squared: 0.0304
# Adjusted R-squared: 0.0268
# Standard Error: 0.0480
# T-statistic: -2.9288
#
# Model Summary:
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const          31.6019      1.843     17.145      0.000      27.973      35.230
# neuroticism    -0.1406      0.048     -2.929      0.004      -0.235      -0.046
# ===============================================================================
#
# ==================================================
# Analysis for risk_sum
# ==================================================
#
# Regression Results for openness predicting risk_sum
# Coefficient: -0.1355
# P-value: 0.0102
# R-squared: 0.0239
# Adjusted R-squared: 0.0203
# Standard Error: 0.0524
# T-statistic: -2.5876
#
# Model Summary:
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         34.1137      2.312     14.758      0.000      29.563      38.664
# openness      -0.1355      0.052     -2.588      0.010      -0.239      -0.032
# ==============================================================================
#
# Regression Results for conscientiousness predicting risk_sum
# Coefficient: 0.0461
# P-value: 0.4403
# R-squared: 0.0022
# Adjusted R-squared: -0.0015
# Standard Error: 0.0596
# T-statistic: 0.7728
#
# Model Summary:
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                26.2104      2.632      9.957      0.000      21.028      31.393
# conscientiousness     0.0461      0.060      0.773      0.440      -0.071       0.163
# =====================================================================================
#
# Regression Results for extraversion predicting risk_sum
# Coefficient: -0.2284
# P-value: 0.0000
# R-squared: 0.0586
# Adjusted R-squared: 0.0552
# Standard Error: 0.0553
# T-statistic: -4.1314
#
# Model Summary:
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const           36.8579      2.127     17.332      0.000      32.671      41.044
# extraversion    -0.2284      0.055     -4.131      0.000      -0.337      -0.120
# ================================================================================
#
# Regression Results for agreeableness predicting risk_sum
# Coefficient: 0.0473
# P-value: 0.5531
# R-squared: 0.0013
# Adjusted R-squared: -0.0024
# Standard Error: 0.0796
# T-statistic: 0.5939
#
# Model Summary:
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            26.0273      3.715      7.005      0.000      18.713      33.341
# agreeableness     0.0473      0.080      0.594      0.553      -0.109       0.204
# =================================================================================
#
# Regression Results for neuroticism predicting risk_sum
# Coefficient: 0.1513
# P-value: 0.0017
# R-squared: 0.0352
# Adjusted R-squared: 0.0317
# Standard Error: 0.0478
# T-statistic: 3.1638
#
# Model Summary:
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const          22.5471      1.836     12.279      0.000      18.932      26.162
# neuroticism     0.1513      0.048      3.164      0.002       0.057       0.245
# ===============================================================================
#
# Regression analysis complete.

# %% [markdown]
# # Process Simulation Data

# %%
# List of thresholds
thresholds = [0]

# List of base target names
base_targets = ['moral', 'risk']

# Generate all target names
targets = [f"{base}_{threshold}_sum" for base in base_targets for threshold in thresholds]

# Perform regression for each predictor and target combination
for target in targets:
    print(f"\n{'='*50}")
    print(f"Analysis for {target}")
    print(f"{'='*50}")
    for predictor in predictors:
        X = data[predictor]
        y = data[target]
        simple_linear_regression(X, y, predictor, target)

print("\nRegression analysis complete.")
# Out:
# ==================================================
# Analysis for moral_0_sum
# ==================================================
#
# Regression Results for openness predicting moral_0_sum
# Coefficient: -0.1376
# P-value: 0.0050
# R-squared: 0.0283
# Adjusted R-squared: 0.0248
# Standard Error: 0.0487
# T-statistic: -2.8268
#
# Model Summary:
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         24.8678      2.149     11.574      0.000      20.638      29.098
# openness      -0.1376      0.049     -2.827      0.005      -0.233      -0.042
# ==============================================================================
#
# Regression Results for conscientiousness predicting moral_0_sum
# Coefficient: 0.1399
# P-value: 0.0115
# R-squared: 0.0231
# Adjusted R-squared: 0.0195
# Standard Error: 0.0550
# T-statistic: 2.5441
#
# Model Summary:
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                12.7824      2.427      5.267      0.000       8.005      17.560
# conscientiousness     0.1399      0.055      2.544      0.012       0.032       0.248
# =====================================================================================
#
# Regression Results for extraversion predicting moral_0_sum
# Coefficient: 0.1080
# P-value: 0.0413
# R-squared: 0.0151
# Adjusted R-squared: 0.0115
# Standard Error: 0.0527
# T-statistic: 2.0504
#
# Model Summary:
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const           14.7993      2.027      7.303      0.000      10.810      18.789
# extraversion     0.1080      0.053      2.050      0.041       0.004       0.212
# ================================================================================
#
# Regression Results for agreeableness predicting moral_0_sum
# Coefficient: -0.2634
# P-value: 0.0003
# R-squared: 0.0459
# Adjusted R-squared: 0.0425
# Standard Error: 0.0725
# T-statistic: -3.6324
#
# Model Summary:
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            31.1011      3.383      9.193      0.000      24.441      37.761
# agreeableness    -0.2634      0.073     -3.632      0.000      -0.406      -0.121
# =================================================================================
#
# Regression Results for neuroticism predicting moral_0_sum
# Coefficient: -0.0586
# P-value: 0.1960
# R-squared: 0.0061
# Adjusted R-squared: 0.0025
# Standard Error: 0.0452
# T-statistic: -1.2960
#
# Model Summary:
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const          21.0820      1.736     12.141      0.000      17.664      24.501
# neuroticism    -0.0586      0.045     -1.296      0.196      -0.148       0.030
# ===============================================================================
#
# ==================================================
# Analysis for risk_0_sum
# ==================================================
#
# Regression Results for openness predicting risk_0_sum
# Coefficient: -0.3474
# P-value: 0.0004
# R-squared: 0.0447
# Adjusted R-squared: 0.0413
# Standard Error: 0.0970
# T-statistic: -3.5824
#
# Model Summary:
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         45.9690      4.280     10.739      0.000      37.542      54.396
# openness      -0.3474      0.097     -3.582      0.000      -0.538      -0.157
# ==============================================================================
#
# Regression Results for conscientiousness predicting risk_0_sum
# Coefficient: -0.0229
# P-value: 0.8377
# R-squared: 0.0002
# Adjusted R-squared: -0.0035
# Standard Error: 0.1117
# T-statistic: -0.2050
#
# Model Summary:
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                31.8618      4.933      6.460      0.000      22.151      41.572
# conscientiousness    -0.0229      0.112     -0.205      0.838      -0.243       0.197
# =====================================================================================
#
# Regression Results for extraversion predicting risk_0_sum
# Coefficient: -1.1322
# P-value: 0.0000
# R-squared: 0.4112
# Adjusted R-squared: 0.4090
# Standard Error: 0.0819
# T-statistic: -13.8317
#
# Model Summary:
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const           73.6710      3.148     23.400      0.000      67.473      79.869
# extraversion    -1.1322      0.082    -13.832      0.000      -1.293      -0.971
# ================================================================================
#
# Regression Results for agreeableness predicting risk_0_sum
# Coefficient: -0.2331
# P-value: 0.1176
# R-squared: 0.0089
# Adjusted R-squared: 0.0053
# Standard Error: 0.1485
# T-statistic: -1.5700
#
# Model Summary:
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            41.6758      6.928      6.016      0.000      28.037      55.315
# agreeableness    -0.2331      0.148     -1.570      0.118      -0.525       0.059
# =================================================================================
#
# Regression Results for neuroticism predicting risk_0_sum
# Coefficient: 0.4554
# P-value: 0.0000
# R-squared: 0.0912
# Adjusted R-squared: 0.0878
# Standard Error: 0.0869
# T-statistic: 5.2424
#
# Model Summary:
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const          13.7810      3.336      4.131      0.000       7.213      20.349
# neuroticism     0.4554      0.087      5.242      0.000       0.284       0.626
# ===============================================================================
#
# Regression analysis complete.

# %%
# List of thresholds
thresholds = [1]

# List of base target names
base_targets = ['moral', 'risk']

moral_scenarios = ["Confidential_Info","Underage_Drinking","Exam_Cheating","Honest_Feedback","Workplace_Theft"]

# Generate all target names
targets = [f"moral_{threshold}_{scenario}" for scenario in moral_scenarios for threshold in thresholds]

# Perform regression for each predictor and target combination
for target in targets:
    print(f"\n{'='*50}")
    print(f"Analysis for {target}")
    print(f"{'='*50}")
    for predictor in predictors:
        X = data[predictor]
        y = data[target]
        simple_linear_regression(X, y, predictor, target)

print("\nRegression analysis complete.")
# Out:
# ==================================================
# Analysis for moral_1_Confidential_Info
# ==================================================
#
# Regression Results for openness predicting moral_1_Confidential_Info
# Coefficient: -0.0319
# P-value: 0.0178
# R-squared: 0.0203
# Adjusted R-squared: 0.0168
# Standard Error: 0.0134
# T-statistic: -2.3847
#
# Model Summary:
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          3.4857      0.591      5.900      0.000       2.323       4.649
# openness      -0.0319      0.013     -2.385      0.018      -0.058      -0.006
# ==============================================================================
#
# Regression Results for conscientiousness predicting moral_1_Confidential_Info
# Coefficient: 0.0017
# P-value: 0.9115
# R-squared: 0.0000
# Adjusted R-squared: -0.0036
# Standard Error: 0.0152
# T-statistic: 0.1112
#
# Model Summary:
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                 2.0239      0.672      3.011      0.003       0.700       3.347
# conscientiousness     0.0017      0.015      0.111      0.912      -0.028       0.032
# =====================================================================================
#
# Regression Results for extraversion predicting moral_1_Confidential_Info
# Coefficient: -0.0192
# P-value: 0.1854
# R-squared: 0.0064
# Adjusted R-squared: 0.0028
# Standard Error: 0.0145
# T-statistic: -1.3276
#
# Model Summary:
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            2.8253      0.557      5.069      0.000       1.728       3.923
# extraversion    -0.0192      0.014     -1.328      0.185      -0.048       0.009
# ================================================================================
#
# Regression Results for agreeableness predicting moral_1_Confidential_Info
# Coefficient: -0.0897
# P-value: 0.0000
# R-squared: 0.0711
# Adjusted R-squared: 0.0677
# Standard Error: 0.0196
# T-statistic: -4.5782
#
# Model Summary:
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             6.2583      0.914      6.846      0.000       4.459       8.058
# agreeableness    -0.0897      0.020     -4.578      0.000      -0.128      -0.051
# =================================================================================
#
# Regression Results for neuroticism predicting moral_1_Confidential_Info
# Coefficient: -0.0139
# P-value: 0.2639
# R-squared: 0.0046
# Adjusted R-squared: 0.0009
# Standard Error: 0.0124
# T-statistic: -1.1196
#
# Model Summary:
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const           2.6181      0.476      5.502      0.000       1.681       3.555
# neuroticism    -0.0139      0.012     -1.120      0.264      -0.038       0.011
# ===============================================================================
#
# ==================================================
# Analysis for moral_1_Underage_Drinking
# ==================================================
#
# Regression Results for openness predicting moral_1_Underage_Drinking
# Coefficient: -0.0459
# P-value: 0.0518
# R-squared: 0.0137
# Adjusted R-squared: 0.0101
# Standard Error: 0.0235
# T-statistic: -1.9531
#
# Model Summary:
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          9.0325      1.038      8.706      0.000       6.990      11.075
# openness      -0.0459      0.024     -1.953      0.052      -0.092       0.000
# ==============================================================================
#
# Regression Results for conscientiousness predicting moral_1_Underage_Drinking
# Coefficient: 0.0578
# P-value: 0.0297
# R-squared: 0.0171
# Adjusted R-squared: 0.0135
# Standard Error: 0.0264
# T-statistic: 2.1852
#
# Model Summary:
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                 4.5167      1.167      3.872      0.000       2.220       6.813
# conscientiousness     0.0578      0.026      2.185      0.030       0.006       0.110
# =====================================================================================
#
# Regression Results for extraversion predicting moral_1_Underage_Drinking
# Coefficient: 0.0114
# P-value: 0.6533
# R-squared: 0.0007
# Adjusted R-squared: -0.0029
# Standard Error: 0.0254
# T-statistic: 0.4496
#
# Model Summary:
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            6.6038      0.978      6.750      0.000       4.678       8.530
# extraversion     0.0114      0.025      0.450      0.653      -0.039       0.062
# ================================================================================
#
# Regression Results for agreeableness predicting moral_1_Underage_Drinking
# Coefficient: 0.0687
# P-value: 0.0528
# R-squared: 0.0136
# Adjusted R-squared: 0.0100
# Standard Error: 0.0353
# T-statistic: 1.9451
#
# Model Summary:
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             3.8482      1.649      2.334      0.020       0.602       7.094
# agreeableness     0.0687      0.035      1.945      0.053      -0.001       0.138
# =================================================================================
#
# Regression Results for neuroticism predicting moral_1_Underage_Drinking
# Coefficient: -0.0432
# P-value: 0.0463
# R-squared: 0.0144
# Adjusted R-squared: 0.0108
# Standard Error: 0.0216
# T-statistic: -2.0018
#
# Model Summary:
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const           8.6565      0.829     10.445      0.000       7.025      10.288
# neuroticism    -0.0432      0.022     -2.002      0.046      -0.086      -0.001
# ===============================================================================
#
# ==================================================
# Analysis for moral_1_Exam_Cheating
# ==================================================
#
# Regression Results for openness predicting moral_1_Exam_Cheating
# Coefficient: -0.0223
# P-value: 0.1796
# R-squared: 0.0066
# Adjusted R-squared: 0.0029
# Standard Error: 0.0166
# T-statistic: -1.3453
#
# Model Summary:
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          3.9303      0.732      5.369      0.000       2.489       5.371
# openness      -0.0223      0.017     -1.345      0.180      -0.055       0.010
# ==============================================================================
#
# Regression Results for conscientiousness predicting moral_1_Exam_Cheating
# Coefficient: -0.0022
# P-value: 0.9078
# R-squared: 0.0000
# Adjusted R-squared: -0.0036
# Standard Error: 0.0187
# T-statistic: -0.1159
#
# Model Summary:
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                 3.0549      0.827      3.693      0.000       1.426       4.683
# conscientiousness    -0.0022      0.019     -0.116      0.908      -0.039       0.035
# =====================================================================================
#
# Regression Results for extraversion predicting moral_1_Exam_Cheating
# Coefficient: -0.0071
# P-value: 0.6926
# R-squared: 0.0006
# Adjusted R-squared: -0.0031
# Standard Error: 0.0179
# T-statistic: -0.3957
#
# Model Summary:
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            3.2277      0.688      4.693      0.000       1.874       4.582
# extraversion    -0.0071      0.018     -0.396      0.693      -0.042       0.028
# ================================================================================
#
# Regression Results for agreeableness predicting moral_1_Exam_Cheating
# Coefficient: -0.0758
# P-value: 0.0023
# R-squared: 0.0335
# Adjusted R-squared: 0.0300
# Standard Error: 0.0246
# T-statistic: -3.0830
#
# Model Summary:
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             6.4763      1.147      5.645      0.000       4.218       8.735
# agreeableness    -0.0758      0.025     -3.083      0.002      -0.124      -0.027
# =================================================================================
#
# Regression Results for neuroticism predicting moral_1_Exam_Cheating
# Coefficient: -0.0243
# P-value: 0.1108
# R-squared: 0.0093
# Adjusted R-squared: 0.0056
# Standard Error: 0.0152
# T-statistic: -1.5997
#
# Model Summary:
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const           3.8727      0.584      6.630      0.000       2.723       5.023
# neuroticism    -0.0243      0.015     -1.600      0.111      -0.054       0.006
# ===============================================================================
#
# ==================================================
# Analysis for moral_1_Honest_Feedback
# ==================================================
#
# Regression Results for openness predicting moral_1_Honest_Feedback
# Coefficient: 0.0121
# P-value: 0.4465
# R-squared: 0.0021
# Adjusted R-squared: -0.0015
# Standard Error: 0.0158
# T-statistic: 0.7624
#
# Model Summary:
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          4.1705      0.699      5.964      0.000       2.794       5.547
# openness       0.0121      0.016      0.762      0.446      -0.019       0.043
# ==============================================================================
#
# Regression Results for conscientiousness predicting moral_1_Honest_Feedback
# Coefficient: 0.0303
# P-value: 0.0895
# R-squared: 0.0105
# Adjusted R-squared: 0.0069
# Standard Error: 0.0178
# T-statistic: 1.7040
#
# Model Summary:
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                 3.3749      0.784      4.303      0.000       1.831       4.919
# conscientiousness     0.0303      0.018      1.704      0.090      -0.005       0.065
# =====================================================================================
#
# Regression Results for extraversion predicting moral_1_Honest_Feedback
# Coefficient: 0.0897
# P-value: 0.0000
# R-squared: 0.1010
# Adjusted R-squared: 0.0977
# Standard Error: 0.0162
# T-statistic: 5.5477
#
# Model Summary:
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            1.3049      0.622      2.099      0.037       0.081       2.529
# extraversion     0.0897      0.016      5.548      0.000       0.058       0.121
# ================================================================================
#
# Regression Results for agreeableness predicting moral_1_Honest_Feedback
# Coefficient: -0.0268
# P-value: 0.2607
# R-squared: 0.0046
# Adjusted R-squared: 0.0010
# Standard Error: 0.0238
# T-statistic: -1.1270
#
# Model Summary:
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             5.9389      1.110      5.352      0.000       3.754       8.123
# agreeableness    -0.0268      0.024     -1.127      0.261      -0.074       0.020
# =================================================================================
#
# Regression Results for neuroticism predicting moral_1_Honest_Feedback
# Coefficient: -0.0208
# P-value: 0.1528
# R-squared: 0.0074
# Adjusted R-squared: 0.0038
# Standard Error: 0.0145
# T-statistic: -1.4338
#
# Model Summary:
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const           5.4759      0.557      9.827      0.000       4.379       6.573
# neuroticism    -0.0208      0.015     -1.434      0.153      -0.049       0.008
# ===============================================================================
#
# ==================================================
# Analysis for moral_1_Workplace_Theft
# ==================================================
#
# Regression Results for openness predicting moral_1_Workplace_Theft
# Coefficient: -0.0318
# P-value: 0.0268
# R-squared: 0.0178
# Adjusted R-squared: 0.0142
# Standard Error: 0.0143
# T-statistic: -2.2269
#
# Model Summary:
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          4.2988      0.630      6.823      0.000       3.059       5.539
# openness      -0.0318      0.014     -2.227      0.027      -0.060      -0.004
# ==============================================================================
#
# Regression Results for conscientiousness predicting moral_1_Workplace_Theft
# Coefficient: -0.0233
# P-value: 0.1498
# R-squared: 0.0076
# Adjusted R-squared: 0.0039
# Standard Error: 0.0162
# T-statistic: -1.4442
#
# Model Summary:
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                 3.9348      0.713      5.516      0.000       2.531       5.339
# conscientiousness    -0.0233      0.016     -1.444      0.150      -0.055       0.008
# =====================================================================================
#
# Regression Results for extraversion predicting moral_1_Workplace_Theft
# Coefficient: -0.0133
# P-value: 0.3908
# R-squared: 0.0027
# Adjusted R-squared: -0.0010
# Standard Error: 0.0155
# T-statistic: -0.8596
#
# Model Summary:
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            3.4192      0.595      5.749      0.000       2.248       4.590
# extraversion    -0.0133      0.015     -0.860      0.391      -0.044       0.017
# ================================================================================
#
# Regression Results for agreeableness predicting moral_1_Workplace_Theft
# Coefficient: -0.0622
# P-value: 0.0038
# R-squared: 0.0301
# Adjusted R-squared: 0.0266
# Standard Error: 0.0213
# T-statistic: -2.9164
#
# Model Summary:
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             5.8010      0.995      5.831      0.000       3.843       7.759
# agreeableness    -0.0622      0.021     -2.916      0.004      -0.104      -0.020
# =================================================================================
#
# Regression Results for neuroticism predicting moral_1_Workplace_Theft
# Coefficient: 0.0069
# P-value: 0.6020
# R-squared: 0.0010
# Adjusted R-squared: -0.0027
# Standard Error: 0.0132
# T-statistic: 0.5221
#
# Model Summary:
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const           2.6578      0.508      5.235      0.000       1.658       3.657
# neuroticism     0.0069      0.013      0.522      0.602      -0.019       0.033
# ===============================================================================
#
# Regression analysis complete.
